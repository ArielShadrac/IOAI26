# %% [markdown]
# # Exercices

# %% [markdown]
# ## Exercice 1 : Créer une couche Linear
#
# Créer une couche :
#
# - entrée : 5 valeurs
# - sortie : 3 valeurs
#
#
# Créer ensuite un tensor d'entrée compatible et afficher la sortie.

# %%
#code

# %% [markdown]
# ## Exercice 2 : Construire un modèle simple
#
# Créer un modèle PyTorch avec :
#
# - une couche Linear (10 → 5)
# - une activation ReLU
# - une couche Linear (5 → 2)
#
#
# Effectuer un forward pass avec une entrée de taille 10.

# %%
#code

# %% [markdown]
# ## Exercice 3 : Modèle FashionMNIST
#
# Créer un modèle avec :
#
# - Flatten
# - Linear (784 → 128)
# - ReLU
# - Linear (128 → 10)
#
#
# Tester le modèle avec une image aléatoire de taille :
#
# [1,28,28]
#
# Afficher la taille de la sortie.

# %%
#code
