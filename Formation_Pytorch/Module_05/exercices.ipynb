# %% [markdown]
# # Exercices
# ## Exercice 1 : Calcul d'un simple gradient
#
# Créer un tensor :
#
# ```python
# x = 5
# ```
#
# avec :
#
# ```python
# requires_grad=True
# ```
#
#
# Calculer :
#
#
# $$y=x^2+3x$$
#
#
# Puis afficher :
#
# - la valeur de y ;
# - le gradient de x.

# %%
#code

# %% [markdown]
# ## Exercice 2 : Gradient d'une fonction
#
# Créer :
#
# $$y=3x^3+2x^2+x$$
#
#
# avec :
#
# ```python
# x = 2
# ```
#
#
# Calculer automatiquement :
#
# $$\frac{dy}{dx}$$
#
#
# Comparer avec le calcul manuel.

# %%
#Code

# %% [markdown]
# ## Exercice 3 : Gradient d'une couche liénaire
#
# Créer une couche :
#
# ```python
# nn.Linear(4,2)
# ```
#
#
# Créer une entrée :
#
# ```python
# [1,2,3,4]
# ```
#
#
# Calculer une sortie puis appliquer :
#
# ```python
# output.sum().backward()
# ```
#
#
# Afficher les gradients des paramètres.

# %%
#code solution
