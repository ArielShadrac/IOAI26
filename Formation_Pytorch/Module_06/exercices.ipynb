# %% [markdown]
# ## Exercice 1 : Créer une fonction de perte
#
# Créer :
#
# ```python
# nn.CrossEntropyLoss()
# ```
#
# Puis calculer la loss entre :
#
# Prédiction :
#
# ```python
# [[1.0, 3.0, 0.5]]
# ```
#
# et
#
# Label :
#
# ```python
# 1
# ```

# %%
#code

# %% [markdown]
# ## Exercice 2 : Créer un optimiseur SGD
#
# Créer un modèle :
#
# ```python
# nn.Linear(5,2)
# ```
#
# Puis créer un optimiseur :
#
# - SGD
# - learning rate = 0.01

# %%
#COde

# %% [markdown]
# ## Exercice 3 : Une étape d'entraînement
#
# Créer :
#
# - un modèle `nn.Linear(3,2)`
# - une entrée aléatoire
# - un label
#
# Effectuer :
#
# 1. Forward pass
# 2. Loss computation
# 3. Backward pass
# 4. Optimizer step
#
# Afficher la loss obtenue.

# %%
#Code
